# %%
import il_pedagogical as ilp
import il_parse as ila
import seaborn as sns

import numpy as np
import matplotlib.pyplot as plt
ini_pool_size = [25, 50, 75, 100]
plt.rcParams.update({'font.size': 18})

# %% [markdown]
# # Gaussian Potential
#
# Look at imoprtance learning results for a Gaussian potential
#
# ## Distribution of $E_a$

# %%
il_gaussian = ila.Parser('logs/g_potential_50.json')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
ilp.histogram(ax1, ax2, il_gaussian.true_barrier_heights(), il_gaussian.T())
fig.tight_layout()

# %% [markdown]
# ## Training the metric learning model, 0th iteration
#
# ### Model barriers predicted on the initial pool

# %%
plt.rcParams['figure.figsize'] = 13, 13
fig = plt.figure()

for i in range(4):
    ax = fig.add_subplot(2, 2, i+1)
    il_gaussian = ila.Parser('logs/g_potential_{}.json'.format(ini_pool_size[i]))
    model_heights = il_gaussian.model_barrier_heights(0)
    initial_pool = il_gaussian.sampled_sites(0)
    true_barriers = il_gaussian.true_barrier_heights()
    plt.title('Iteration 0, Initial Pool = {}'.format(ini_pool_size[i]))
    ilp.plot_trained(ax, model_heights[initial_pool], true_barriers[initial_pool], 2.5, len(initial_pool))
    
plt.show()

# %% [markdown]
# ### Distribution of residuals
#
# Mostly Gaussian

# %%
plt.rcParams['figure.figsize'] = 13, 13
fig = plt.figure()

for i in range(4):
    ax = fig.add_subplot(2, 2, i+1)
    il_gaussian = ila.Parser('logs/g_potential_{}.json'.format(ini_pool_size[i]))
    model_heights = il_gaussian.model_barrier_heights(0)
    initial_pool = il_gaussian.sampled_sites(0)
    true_barriers = il_gaussian.true_barrier_heights()
    ilp.plot_residuals(ax, true_barriers, model_heights)
    plt.title('Iteration 0, Initial Pool = {}'.format(ini_pool_size[i]))

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Importance Learning Convergence

# %%
plt.rcParams['figure.figsize'] = 13, 13
plt.rcParams.update({'font.size': 18})

fig = plt.figure()
for i in range(4):
    ax = fig.add_subplot(2, 2, i+1)
    il_gaussian = ila.Parser('logs/g_potential_{}.json'.format(ini_pool_size[i]))

    avg_Ea_exact = il_gaussian.true_site_avg_Ea()
    avg_Ea_pred = il_gaussian.all_site_avg_Ea()
    avg_Ea_pred_err = il_gaussian.all_site_Ea_sampling_error()
    n_iterations =il_gaussian.n_iterations

#     plt.subplot(2,2,i+1)
    plt.title('IS Convergence, Initial Pool = {}'.format(ini_pool_size[i]))
    ilp.plot_convergence(ax, n_iterations, avg_Ea_pred, avg_Ea_pred_err, avg_Ea_exact, 10)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Final Iteration

# %%
il_gaussian = ila.Parser('logs/g_potential_{}.json'.format(ini_pool_size[1]))
model_heights = il_gaussian.model_barrier_heights(25)
sampled_sites = il_gaussian.sampled_sites(25)

# %% [markdown]
# ## Model Distributions

# %%
fig, axs = plt.subplots(4, 2, figsize=(10,15))

for i in range(4):
    axs[i, 0].title.set_text('Initial Pool = {}'.format(ini_pool_size[i]))
    ilp.histogram(axs[i, 0], axs[i, 1], model_heights, il_gaussian.T(), 20)

plt.tight_layout()

# %%
plt.rcParams['figure.figsize'] = 7, 7
plt.rcParams.update({'font.size': 18})
# ilp.plot_trained(model_heights[initial_pool]+50, true_barriers[initial_pool]+50, 2.5, len(initial_pool))
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

il_gaussian = ila.Parser('logs/g_potential_50.json'.format(50))
model_heights = il_gaussian.model_barrier_heights(0)
initial_pool = il_gaussian.sampled_sites(0)
true_barriers = il_gaussian.true_barrier_heights()
ilp.plot_residuals(ax, true_barriers, model_heights)
plt.title('Residuals of Model Predicted Barriers on all Sites'.format(50))
# Out:
# Text(0.5,1,'Iteration 0, Initial Pool = 50')
