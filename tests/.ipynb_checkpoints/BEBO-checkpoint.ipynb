# %%
import sys
sys.path.append('../')
# %matplotlib notebook
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt

import il_pedagogical as ilp

# %%
A = 3264.7
B = 95.373*5
l1 = 3.2394 * 2.33
l2 = 1.35258 * 2.33
l3 = l2


# A = 3164.7/100
# B = 900.373/100

# l1 = 5.25
# l2 = 0.9
# l3 = l2

beta = 0.33975
n = 22.956
# n = 12.956

def energy(coords, p):
    x, y = coords
    return sum([A*np.exp(-l1 * dist(x, p[i, 0], y, p[i, 1])) - BO(x, y, i, p, beta, l3, n) * B *np.exp(-l2 * dist(x, p[i, 0], y, p[i, 1])) for i in range(len(p))])

def BO(x, y, i, p, beta, l3, n):
    thing = [np.exp(l3**3 * (dist(x, p[i, 0], y, p[i, 1]) - dist(x, p[k, 0], y, p[k, 1]))**3) for k in range(len(p)) if k !=i ]
    return (1 + beta**n * np.sum(thing))**(-0.5 * n)
    
def dist(xm, xi, ym, yi):
    return np.sqrt((xm - xi)**2 + (ym - yi)**2)

# %%
fig, ax = plt.subplots(1, 1, figsize=(5,4))
lattice_size = 20
a = 35 # ~ Potential width, dimensionless
D = 60 # Potential depth, kJ/mol
r_eq = 1.0 # Equilibrium distance of unperturbed lattice, dimensionless
T = 300
delta = 0.25
gauss_pot_std = 0.9
dissociation_type = 2
potential_type = 2

displacement_type = 'uniform'
lattice = ilp.make_quenched_disorder_lattice(lattice_size, delta, displacement_type, False, seed=True)
ilp.plot_lattice(lattice)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
fig, ax = plt.subplots(1, 1, figsize=(7,6))
p = lattice[4:6, 4:6].reshape(4,2)
# p = lattice[2, 2].reshape(1,2)

lower = 3
upper = 6

xaxis = np.linspace(lower, upper, 100)
yaxis = np.linspace(lower, upper, 100)
x, y = np.meshgrid(xaxis, yaxis)

energy_landscape = energy((x, y), p)
initial_guess = np.asarray([4.5, 4.5])
result = minimize(energy, initial_guess, args=p)

plt.contourf(energy_landscape, extent=[lower, upper, lower, upper], levels=15)
plt.colorbar()

plt.scatter(initial_guess[0], initial_guess[1], s=100, c="white", marker='x', label="initial guess")
plt.scatter(result.x[0], result.x[1], s=100, c="red", marker='x', label="minimum")
plt.legend()
plt.show()

print('Optmized gemoetry: ({:03.3f}, {:03.3f})'.format(result.x[0], result.x[1]))
# Out:
# <img src="data:image/png;base64,..." width="700">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-ce390d49caa8> in <module>()
#      14 result = minimize(energy, initial_guess, args=p)
#      15
# ---> 16 plt.contourf(energy_landscape, extent=[lower, upper, lower, upper], levels=15)
#      17 plt.colorbar()
#      18
#
# c:\users\salman\appdata\local\programs\python\python36\lib\site-packages\matplotlib\pyplot.py in contourf(*args, **kwargs)
#    2828                       mplDeprecation)
#    2829     try:
# -> 2830         ret = ax.contourf(*args, **kwargs)
#    2831     finally:
#    2832         ax._hold = washold
#
# c:\users\salman\appdata\local\programs\python\python36\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1843                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
p = lattice[0:10, 0:10].reshape(100,2)

lower = -0.5
upper = 10.5

xaxis = np.linspace(lower, upper, 200)
yaxis = np.linspace(lower, upper, 200)
x, y = np.meshgrid(xaxis, yaxis)
 
energy_landscape = energy((x, y), p)
# Out:
# /home/craig/.local/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: overflow encountered in exp
# /home/craig/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
fig, ax = plt.subplots(1, 1, figsize=(9,8))


initial_guess = np.asarray([0.75, 2.5])
result = minimize(energy, initial_guess, args=( p))

plt.contourf(energy_landscape, extent=[lower, upper, lower, upper], levels=40)
plt.colorbar()

plt.scatter(initial_guess[0], initial_guess[1], s=100, c="green", marker='x', label="initial guess")
plt.scatter(result.x[0], result.x[1], s=100, c="red", marker='x', label="minimum")
plt.legend()
plt.show()

print('Optmized gemoetry: ({:03.3f}, {:03.3f})'.format(result.x[0], result.x[1]))
# Out:
# <img src="data:image/png;base64,..." width="900">
# /home/craig/.local/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: overflow encountered in exp
# Optmized gemoetry: (0.686, 2.497)

# %%
energy_landscape = energy((x, y), p)
initial_guess = np.asarray([3.5, 3.5])
result = minimize(energy, initial_guess, args=( p))
print(result.x)
print(x)
# Out:
# [3.61833669 3.54777764]
# [[2.5        2.52020202 2.54040404 ... 4.45959596 4.47979798 4.5       ]
#  [2.5        2.52020202 2.54040404 ... 4.45959596 4.47979798 4.5       ]
#  [2.5        2.52020202 2.54040404 ... 4.45959596 4.47979798 4.5       ]
#  ...
#  [2.5        2.52020202 2.54040404 ... 4.45959596 4.47979798 4.5       ]
#  [2.5        2.52020202 2.54040404 ... 4.45959596 4.47979798 4.5       ]
#  [2.5        2.52020202 2.54040404 ... 4.45959596 4.47979798 4.5       ]]

# %%
fig, ax = plt.subplots(1, 1, figsize=(7,6))
plt.plot(x, energy_landscape)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
def energy2(coords, p):
    x, y = coords
    return sum([A*np.exp(-l1 * dist(x, p[i, 0], y, p[i, 1])) - BO(x, y, i, p, beta, l3, n) * B *np.exp(-l2 * dist(x, p[i, 0], y, p[i, 1])) for i in range(len(p))])

def BO2(x, y, i, p, beta, l3, n):
    thing = [np.exp(l3**3 * (dist(x, p[i, 0], y, p[i, 1]) - dist(x, p[k, 0], y, p[k, 1]))**3) for k in range(len(p)) if k !=i ]
    return (1 + beta**n * np.sum(thing))**(-0.5 * n)
# Out:
# array([[-337.39631276, -342.70074563, -347.91824271, ..., -185.19648381,
#         -180.37204559, -175.63256414],
#        [-337.39631276, -342.70074563, -347.91824271, ..., -185.19648381,
#         -180.37204559, -175.63256414],
#        [-337.39631276, -342.70074563, -347.91824271, ..., -185.19648381,
#         -180.37204559, -175.63256414],
#        ...,
#        [-337.39631276, -342.70074563, -347.91824271, ..., -185.19648381,
#         -180.37204559, -175.63256414],
#        [-337.39631276, -342.70074563, -347.91824271, ..., -185.19648381,
#         -180.37204559, -175.63256414],
#        [-337.39631276, -342.70074563, -347.91824271, ..., -185.19648381,
#         -180.37204559, -175.63256414]])
